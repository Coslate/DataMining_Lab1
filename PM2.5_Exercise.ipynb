# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Customizing plots with style 
from pylab import rcParams

rcParams['figure.figsize'] = 10, 5
rcParams['lines.linewidth'] = 2
plt.style.use('ggplot')

# %%
pm25_data = pd.read_csv('data/PM2.5/PM2.5_20160911_small.csv')
pm25_data.head(5)#讀前十筆資料
# pm25_data.tail(10)
#s_h0 濕度
#s_t0 溫度
#s_d0 pm2.5
#s_d1 pm10
# Out:
#   device_id             datatime   app  gps_x  gps_y  gps_z     gps_lon  \
# 0   FT1_041  2016-09-10 06:29:18  PM25    0.0    0.0    0.0  121.517933
# 1   FT1_041  2016-09-10 06:29:18  PM25    0.0    0.0    0.0  121.517933
# 2   FT1_041  2016-09-10 06:30:18  PM25    0.0    0.0    0.0  121.517933
# 3   FT1_041  2016-09-10 06:30:18  PM25    0.0    0.0    0.0  121.517933
# 4   FT1_041  2016-09-10 06:31:17  PM25    0.0    0.0    0.0  121.517933
#
#      gps_lat  gps_alt  ver_format  ...         tick    s_1      s_0  s_3  s_2  \
# 0  24.985072     27.0           3  ...    765376376  100.0  12808.0  0.0  1.0
# 1  24.985072     27.0           3  ...    765376376  100.0  12808.0  0.0  1.0
# 2  24.985072     27.0           3  ...    765436128  100.0  12809.0  0.0  1.0
# 3  24.985072     27.0           3  ...    765436128  100.0  12809.0  0.0  1.0
# 4  24.985072     27.0           3  ...    765495888  100.0  12810.0  0.0  1.0
#
#    s_4   s_t0  s_d0  s_d1   s_h0
# ...

# %%
pm25_data['datatime'].unique()
# Out:
# array(['2016-09-10 06:29:18', '2016-09-10 06:30:18', '2016-09-10 06:31:17',
#        ..., '2016-09-11 06:26:00', '2016-09-11 06:26:59',
#        '2016-09-11 06:28:00'], dtype=object)

# %%
pm25_data
# Out:
#       device_id             datatime   app  gps_x  gps_y  gps_z     gps_lon  \
# 0       FT1_041  2016-09-10 06:29:18  PM25    0.0    0.0    0.0  121.517933
# 1       FT1_041  2016-09-10 06:29:18  PM25    0.0    0.0    0.0  121.517933
# 2       FT1_041  2016-09-10 06:30:18  PM25    0.0    0.0    0.0  121.517933
# 3       FT1_041  2016-09-10 06:30:18  PM25    0.0    0.0    0.0  121.517933
# 4       FT1_041  2016-09-10 06:31:17  PM25    0.0    0.0    0.0  121.517933
# 5       FT1_041  2016-09-10 06:31:17  PM25    0.0    0.0    0.0  121.517933
# 6       FT1_041  2016-09-10 06:32:17  PM25    0.0    0.0    0.0  121.517933
# 7       FT1_041  2016-09-10 06:32:17  PM25    0.0    0.0    0.0  121.517933
# 8       FT1_041  2016-09-10 06:33:18  PM25    0.0    0.0    0.0  121.517982
# 9       FT1_041  2016-09-10 06:33:18  PM25    0.0    0.0    0.0  121.517982
# 10      FT1_041  2016-09-10 06:34:17  PM25    0.0    0.0    0.0  121.517982
# ...

# %%
#pm25_data[['datatime', 's_d0', 's_d1', 's_t0', 's_h0']]
pm25_data_s_t0_spec = pm25_data[(pm25_data.s_t0 == 15.2)]
pm25_data_s_t0_spec
#pm25_data[(pm25_data.datatime == '2016-09-10 22:17:48')]
#max(pm25_data['s_t0'])
#min(pm25_data['s_t0'])
#max(pm25_data['datatime'])
#min(pm25_data['datatime'])
# Out:
#       device_id             datatime   app  gps_x  gps_y  gps_z     gps_lon  \
# 5321    FT1_028  2016-09-11 05:28:13  PM25    0.0    0.0    0.0  121.541130
# 10212   FT1_035  2016-09-11 00:44:08  PM25    0.0    0.0    0.0  121.454012
# 10213   FT1_035  2016-09-11 00:44:08  PM25    0.0    0.0    0.0  121.454012
#
#          gps_lat  gps_alt  ver_format  ...         tick    s_1       s_0  \
# 5321   24.975617      2.0           3  ...   3249273228  100.0  255376.0
# 10212  24.982070     30.0           3  ...    682835586  100.0   22841.0
# 10213  24.982070     30.0           3  ...    682835586  100.0   22841.0
#
#         s_3  s_2    s_4  s_t0  s_d0  s_d1  s_h0
# 5321   0.17  1.0  535.0  15.2  32.0  46.0   1.0
# 10212  0.00  1.0    1.0  15.2  17.0  29.0  99.9
# 10213  0.00  1.0    1.0  15.2  17.0  29.0  99.9
#
# [3 rows x 23 columns]

# %%
pm25_data_s_h0_spec = pm25_data[(pm25_data.s_h0 == 0)]
pm25_data_s_h0_spec
# Out:
#       device_id             datatime   app  gps_x  gps_y  gps_z     gps_lon  \
# 11574   FT1_037  2080-01-06 00:00:14  PM25    0.0    0.0    0.0  121.553390
# 11575   FT1_037  2080-01-06 00:00:14  PM25    0.0    0.0    0.0  121.553390
# 11783   FT1_037  2080-01-06 00:00:14  PM25    0.0    0.0    0.0  121.553227
# 11784   FT1_037  2080-01-06 00:00:14  PM25    0.0    0.0    0.0  121.553227
# 11785   FT1_037  2016-09-10 17:10:14  PM25    0.0    0.0    0.0  121.553227
# 11786   FT1_037  2016-09-10 17:10:14  PM25    0.0    0.0    0.0  121.553227
# 11787   FT1_037  2016-09-10 17:10:44  PM25    0.0    0.0    0.0  121.660485
# 11788   FT1_037  2016-09-10 17:10:44  PM25    0.0    0.0    0.0  121.660485
# 11937   FT1_037  2016-09-10 17:48:48  PM25    0.0    0.0    0.0  121.553448
# 11938   FT1_037  2016-09-10 17:48:48  PM25    0.0    0.0    0.0  121.553448
# 12095   FT1_037  2080-01-05 23:59:48  PM25    0.0    0.0    0.0  121.553307
#
# ...

# %%
pm25_data[['s_d0', 's_d1', 's_t0', 's_h0']].plot(title = 'PM2.5, PM10, Humidity and Temperature', xlim = (0, 5))

# %%
pm25_data.groupby('datatime')[['s_d0', 's_d1', 's_t0', 's_h0']].mean()
# Out:
#                      s_d0  s_d1   s_t0   s_h0
# datatime
# 2016-09-10 06:24:01  16.0  28.0  31.10  98.30
# 2016-09-10 06:24:31  17.0  26.0  31.20  98.30
# 2016-09-10 06:25:00  17.0  27.0  31.10  98.30
# 2016-09-10 06:25:30  16.0  28.0  31.10  98.30
# 2016-09-10 06:26:00  16.0  30.0  31.10  98.40
# 2016-09-10 06:26:30  17.0  26.0  31.10  98.40
# 2016-09-10 06:27:00  15.0  31.0  31.10  98.40
# 2016-09-10 06:27:30  20.0  27.0  31.20  97.90
# 2016-09-10 06:28:00  20.0  28.0  31.20  98.30
# 2016-09-10 06:28:30  19.0  28.0  31.10  98.30
# 2016-09-10 06:28:36  11.0  12.0  32.80   1.40
# 2016-09-10 06:28:51  14.0  15.0  29.70  73.20
# 2016-09-10 06:28:57  18.0  33.0  26.10  99.90
# 2016-09-10 06:29:00  17.0  28.0  31.10  98.30
# 2016-09-10 06:29:09  14.0  18.0  29.33  80.30
# 2016-09-10 06:29:18  14.0  17.0  28.89  83.12
# 2016-09-10 06:29:23  14.0  14.0  29.30  22.60
# 2016-09-10 06:29:30  16.0  27.0  31.10  98.30
# 2016-09-10 06:29:36  10.0  10.0  32.90   1.40
# ...

# %%
pm25_data[(pm25_data.datatime == '2016-09-10 22:17:48')]
# Out:
#       device_id             datatime   app  gps_x  gps_y  gps_z     gps_lon  \
# 13006   FT1_037  2016-09-10 22:17:48  PM25    0.0    0.0    0.0  121.553135
# 13007   FT1_037  2016-09-10 22:17:48  PM25    0.0    0.0    0.0  121.553135
#
#         gps_lat  gps_alt  ver_format  ...       tick    s_1    s_0  s_3  s_2  \
# 13006  25.05498     56.0           3  ...   13667228  100.0  457.0  0.0  1.0
# 13007  25.05498     56.0           3  ...   13667228  100.0  457.0  0.0  1.0
#
#        s_4  s_t0  s_d0  s_d1  s_h0
# 13006  2.0  29.3  79.0  81.0  88.5
# 13007  2.0  29.3  79.0  81.0  88.5
#
# [2 rows x 23 columns]

# %%
pm25_datatime_data = pm25_data.groupby('datatime')[['s_d0', 's_d1', 's_t0']].mean()
size = len(pm25_datatime_data)
pm25_datatime_data.plot(title = 'PM2.5, PM10, Humidity and Temperature', rot = 70, xticks = range(0, size, int(size/48)))

# %%
len(pm25_data.groupby('datatime')[['s_d0', 's_d1', 's_t0']].mean())
# Out:
# 10846

# %%
pm25_datatime_data = pm25_data.groupby('datatime')[['s_d0', 's_d1', 's_t0']].mean()
pm25_datatime_thresh_sd0 = pm25_datatime_data[pm25_datatime_data.s_d0 > 36]
size = len(pm25_datatime_thresh_sd0)
pm25_datatime_thresh_sd0.plot(title = 'PM2.5, PM10 and Temperature', rot = 70, xticks = range(0, size, int(size/8)))

# %%
pm25_datatime_data = pm25_data.groupby('datatime')[['s_d0', 's_d1', 's_t0']].mean()
pm25_datatime_thresh_sd1 = pm25_datatime_data[pm25_datatime_data.s_d1 > 36]
size = len(pm25_datatime_thresh_sd1)
pm25_datatime_thresh_sd1.plot(title = 'PM2.5, PM10 and Temperature', rot = 70, xticks = range(0, size, int(size/8)))

# %%
print(f"len = {len(pm25_datatime_thresh_sd0)}")
pm25_datatime_thresh_sd0
# Out:
# len = 27
#                           s_d0       s_d1       s_t0
# datatime
# 2016-09-10 21:47:24  46.000000  48.000000  29.100000
# 2016-09-10 21:47:54  49.000000  51.000000  29.100000
# 2016-09-10 21:48:24  47.000000  48.000000  29.100000
# 2016-09-10 21:48:54  43.000000  45.000000  29.100000
# 2016-09-10 21:49:23  37.000000  38.000000  29.100000
# 2016-09-10 22:15:49  60.000000  64.000000  29.300000
# 2016-09-10 22:16:48  76.000000  80.000000  29.300000
# 2016-09-10 22:17:18  77.000000  80.000000  29.300000
# 2016-09-10 22:17:48  79.000000  81.000000  29.300000
# 2016-09-10 22:18:18  53.333333  56.000000  29.933333
# 2016-09-10 22:18:49  73.000000  76.000000  29.300000
# 2016-09-10 22:19:18  49.333333  55.333333  29.900000
# 2016-09-10 22:19:48  68.000000  71.000000  29.300000
# 2016-09-10 22:20:18  46.666667  48.333333  28.233333
# 2016-09-10 22:20:48  55.000000  58.000000  26.700000
# 2016-09-10 22:21:18  42.666667  45.666667  29.866667
# ...

# %%
pm25_datatime_data = pm25_data.groupby('datatime')[['s_d0', 's_d1', 's_t0']].mean()
pm25_datatime_thresh_sd1 = pm25_datatime_data[pm25_datatime_data.s_d1 > 55]
size = len(pm25_datatime_thresh_sd1)
pm25_datatime_thresh_sd1.plot(title = 'PM10 Larger Than 55(ug/m3)', rot = 70, xticks = range(0, size, int(size/8)))

# %%
print(f"len = {len(pm25_datatime_thresh_sd1)}")
pm25_datatime_thresh_sd1
# Out:
# len = 9
#                           s_d0       s_d1       s_t0
# datatime
# 2016-09-10 22:15:49  60.000000  64.000000  29.300000
# 2016-09-10 22:16:48  76.000000  80.000000  29.300000
# 2016-09-10 22:17:18  77.000000  80.000000  29.300000
# 2016-09-10 22:17:48  79.000000  81.000000  29.300000
# 2016-09-10 22:18:18  53.333333  56.000000  29.933333
# 2016-09-10 22:18:49  73.000000  76.000000  29.300000
# 2016-09-10 22:19:18  49.333333  55.333333  29.900000
# 2016-09-10 22:19:48  68.000000  71.000000  29.300000
# 2016-09-10 22:20:48  55.000000  58.000000  26.700000

# %%
pm25_datatime_data = pm25_data.groupby('datatime')[['s_d0', 's_d1', 's_t0']].mean()
pm25_datatime_thresh_sd0_sd1 = pm25_datatime_data[(pm25_datatime_data.s_d0 > 36) | (pm25_datatime_data.s_d1>55)]
size = len(pm25_datatime_thresh_sd0_sd1)
pm25_datatime_thresh_sd0_sd1.plot(title = 'PM2.5, PM10 and Temperature', rot = 70, xticks = range(0, size, int(size/8)))

# %%
print(f"len = {len(pm25_datatime_thresh_sd0_sd1)}")
pm25_datatime_thresh_sd0_sd1
# Out:
# len = 27
#                           s_d0       s_d1       s_t0
# datatime
# 2016-09-10 21:47:24  46.000000  48.000000  29.100000
# 2016-09-10 21:47:54  49.000000  51.000000  29.100000
# 2016-09-10 21:48:24  47.000000  48.000000  29.100000
# 2016-09-10 21:48:54  43.000000  45.000000  29.100000
# 2016-09-10 21:49:23  37.000000  38.000000  29.100000
# 2016-09-10 22:15:49  60.000000  64.000000  29.300000
# 2016-09-10 22:16:48  76.000000  80.000000  29.300000
# 2016-09-10 22:17:18  77.000000  80.000000  29.300000
# 2016-09-10 22:17:48  79.000000  81.000000  29.300000
# 2016-09-10 22:18:18  53.333333  56.000000  29.933333
# 2016-09-10 22:18:49  73.000000  76.000000  29.300000
# 2016-09-10 22:19:18  49.333333  55.333333  29.900000
# 2016-09-10 22:19:48  68.000000  71.000000  29.300000
# 2016-09-10 22:20:18  46.666667  48.333333  28.233333
# 2016-09-10 22:20:48  55.000000  58.000000  26.700000
# 2016-09-10 22:21:18  42.666667  45.666667  29.866667
# ...

# %%
pm25_datatime_data = pm25_data.groupby('datatime')[['s_d0', 's_d1', 's_t0']].mean()
pm25_datatime_thresh_sd0_sd1 = pm25_datatime_data[(pm25_datatime_data.s_d0 > 36) & (pm25_datatime_data.s_d1>55)]
size = len(pm25_datatime_thresh_sd0_sd1)
pm25_datatime_thresh_sd0_sd1.plot(title = 'PM2.5, PM10 and Temperature', rot = 70, xticks = range(0, size, int(size/8)))

# %%
pm25_data[(pm25_data.gps_x > 0) | (pm25_data.gps_y > 0) | (pm25_data.gps_z > 0)]
# Out:
# Empty DataFrame
# Columns: [device_id, datatime, app, gps_x, gps_y, gps_z, gps_lon, gps_lat, gps_alt, ver_format, ver_app, device, fmt_opt, tick, s_1, s_0, s_3, s_2, s_4, s_t0, s_d0, s_d1, s_h0]
# Index: []
#
# [0 rows x 23 columns]

# %%
#pm25_temperature_data = pm25_data.groupby(pm25_data['s_t0'])[['s_d0', 's_d1']].mean()
pm25_temperature_data = pm25_data.groupby('s_t0')[['s_d0', 's_d1']].mean()
max_tmp = max(pm25_data['s_t0'])
min_tmp = min(pm25_data['s_t0'])
tmp_range = int(max_tmp - min_tmp)
print("max_tmp = {x}".format(x = max_tmp))
print("min_tmp = {x}".format(x = min_tmp))
print("tmp_range = {x}".format(x = tmp_range))
pm25_temperature_data.plot(title = 'PM2.5 and PM10 VS Temperature', rot = 70, xticks = range(int(min_tmp), int(max_tmp)+1, 2))
# Out:
# max_tmp = 39.8
# min_tmp = 0.0
# tmp_range = 39

# %%
#pm25_humidity_data = pm25_data.groupby(pm25_data['s_h0'])[['s_d0', 's_d1']].mean()
pm25_humidity_data = pm25_data.groupby('s_h0')[['s_d0', 's_d1']].mean()
max_hum = max(pm25_data['s_h0'])
min_hum = min(pm25_data['s_h0'])
hum_range = int(max_hum - min_hum)
print("max_hum = {x}".format(x = max_hum))
print("min_hum = {x}".format(x = min_hum))
print("hum_range = {x}".format(x = hum_range))
pm25_humidity_data.plot(title = 'PM2.5 and PM10 VS Humidity', rot = 70, xticks = range(int(min_hum), int(max_hum)+1, 5))
# Out:
# max_hum = 99.9
# min_hum = 0.0
# hum_range = 99

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

pm25_humidity_temperature_data = pm25_data.groupby(['s_h0','s_t0'])[['s_d0', 's_d1']].mean()
pm25_humidity_temperature_data
#max_hum = max(pm25_data['s_h0'])
#min_hum = min(pm25_data['s_h0'])
#hum_range = int(max_hum - min_hum)
#print("max_hum = {x}".format(x = max_hum))
#print("min_hum = {x}".format(x = min_hum))
#print("hum_range = {x}".format(x = hum_range))
pm25_humidity_temperature_data.plot(title = 'PM2.5 and PM10 VS (Humidity, Temperature)', rot = 70)

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

pm25_temperature_humidity_data = pm25_data.groupby(['s_t0','s_h0'])[['s_d0', 's_d1']].mean()
pm25_temperature_humidity_data.plot(title = 'PM2.5 and PM10 VS (Temperature, Humidity)', rot = 70)

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

pm25_temperature_humidity_data = pm25_data.groupby(['s_t0','s_h0'])[['s_d0', 's_d1']].mean()
print(pm25_temperature_humidity_data)
# Out:
#                   s_d0       s_d1
# s_t0  s_h0
# 0.00  0.00    8.090909   8.636364
# 15.20 1.00   32.000000  46.000000
#       99.90  17.000000  29.000000
# 15.90 99.90  16.000000  26.000000
# 16.90 1.00    4.000000  17.000000
# 17.60 99.90  17.000000  30.000000
# 17.70 1.00    7.000000  21.000000
# 18.10 84.70  21.000000  32.000000
# 18.40 99.90  18.500000  29.500000
# 18.50 81.90  15.000000  16.000000
# 18.80 56.00  28.000000  31.000000
# 20.00 99.90  16.000000  25.000000
# 21.50 91.10   5.500000   5.500000
# 23.90 99.90  22.000000  35.000000
# 24.30 99.90  21.000000  35.000000
# 25.00 99.90  17.500000  30.000000
# 25.10 99.90  20.315789  34.052632
# 25.20 74.80   8.000000   8.500000
#       99.90  20.094118  33.376471
# 25.30 99.90  20.364865  33.743243
# 25.40 99.90  20.035088  33.280702
# 25.50 74.90  10.000000  11.000000
#       92.20  15.000000  23.000000
#       99.90  20.507463  33.910448
# 25.60 1.40   15.500000  16.500000
#       7.20    6.000000  19.000000
# ...

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

pm25_temperature_humidity_data = pm25_data.groupby(['s_t0','s_h0'])[['s_d0', 's_d1']].mean()
group_keys = pm25_data.groupby(['s_t0','s_h0']).groups.keys()
type(group_keys)
for items in group_keys : 
    (temp, hum) = items
    print("{x}, {y}".format(x = temp, y = hum))
# Out:
# 0.0, 0.0
# 15.2, 1.0
# 15.2, 99.9
# 15.9, 99.9
# 16.9, 1.0
# 17.6, 99.9
# 17.7, 1.0
# 18.1, 84.7
# 18.4, 99.9
# 18.5, 81.9
# 18.8, 56.0
# 20.0, 99.9
# 21.5, 91.1
# 23.9, 99.9
# 24.3, 99.9
# 25.0, 99.9
# 25.1, 99.9
# 25.2, 74.8
# 25.2, 99.9
# 25.3, 99.9
# 25.4, 99.9
# 25.5, 74.9
# 25.5, 92.2
# 25.5, 99.9
# 25.6, 1.4
# 25.6, 7.2
# 25.6, 25.5
# 25.6, 55.3
# 25.6, 55.6
# 25.6, 74.2
# 25.6, 74.9
# 25.6, 90.2
# 25.6, 90.8
# 25.6, 95.2
# 25.6, 99.9
# 25.66, 94.19
# 25.68, 93.0
# 25.68, 93.22
# 25.7, 1.0
# 25.7, 1.4
# 25.7, 75.0
# 25.7, 88.0
# 25.7, 93.12
# 25.7, 93.18
# 25.7, 99.7
# 25.7, 99.9
# 25.71, 93.61
# 25.71, 93.92
# 25.72, 92.05
# 25.72, 92.41
# 25.72, 92.65
# 25.72, 94.14
# 25.73, 91.8
# 25.73, 92.21
# 25.73, 92.69
# 25.73, 92.73
# 25.73, 93.1
# 25.73, 93.34
# 25.74, 94.1
# 25.75, 91.65
# 25.75, 92.22
# 25.75, 92.69
# 25.75, 92.87
# 25.75, 93.32
# 25.75, 93.34
# 25.75, 93.37
# 25.75, 93.82
# 25.76, 91.66
# 25.76, 91.76
# 25.76, 91.9
# 25.76, 92.17
# 25.76, 92.75
# 25.76, 93.24
# ...

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

pm25_temperature_humidity_data = pm25_data.groupby(['s_t0','s_h0'])[['s_d0', 's_d1']]
pm25_temperature_humidity_data_mean = pm25_temperature_humidity_data.mean()
#print(pm25_temperature_humidity_data_mean[['s_d0', 's_d1']])
#print("=================")
#print(pm25_temperature_humidity_data_mean['s_d0'])

print(pm25_data[(pm25_data.s_t0==15.2)])
#pm25_temperature_data = pm25_data.groupby(['s_t0', 's_h0'])[['s_d0', 's_d1']]
print(pm25_temperature_humidity_data.get_group((0, 0))['s_d0'])
print(type(pm25_temperature_humidity_data.get_group((0, 0))['s_d0']))

for val in pm25_temperature_humidity_data.get_group((0, 0))['s_d0']:
    print("val = {x}".format(x = val))
    
pm25_temperature_humidity_data_mean
# Out:
#       device_id             datatime   app  gps_x  gps_y  gps_z     gps_lon  \
# 5321    FT1_028  2016-09-11 05:28:13  PM25    0.0    0.0    0.0  121.541130
# 10212   FT1_035  2016-09-11 00:44:08  PM25    0.0    0.0    0.0  121.454012
# 10213   FT1_035  2016-09-11 00:44:08  PM25    0.0    0.0    0.0  121.454012
#
#          gps_lat  gps_alt  ver_format  ...         tick    s_1       s_0  \
# 5321   24.975617      2.0           3  ...   3249273228  100.0  255376.0
# 10212  24.982070     30.0           3  ...    682835586  100.0   22841.0
# 10213  24.982070     30.0           3  ...    682835586  100.0   22841.0
#
#         s_3  s_2    s_4  s_t0  s_d0  s_d1  s_h0
# 5321   0.17  1.0  535.0  15.2  32.0  46.0   1.0
# 10212  0.00  1.0    1.0  15.2  17.0  29.0  99.9
# 10213  0.00  1.0    1.0  15.2  17.0  29.0  99.9
#
# [3 rows x 23 columns]
# 11574    11.0
# 11575    11.0
# 11783     7.0
# 11784     7.0
# 11785     7.0
# 11786     7.0
# 11787     8.0
# 11788     8.0
# 11937     9.0
# ...

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

pm25_temperature_humidity_data_group = pm25_data.groupby(['s_t0','s_h0'])[['s_d0', 's_d1']]
pm25_temperature_humidity_data_mean = pm25_temperature_humidity_data_group.mean()
group_keys = pm25_temperature_humidity_data_group.groups.keys()

temp = []
hum = []
for items in group_keys : 
    (temp_val, hum_val) = items
    temp.append(temp_val)
    hum.append(hum_val)
    
s_d0_l = []
for items in pm25_temperature_humidity_data_mean['s_d0']:
    s_d0_l.append(items)

    
plt.figure(1)
threedee = plt.figure().gca(projection='3d')
#threedee.scatter(temp, hum, pm25_temperature_humidity_data_mean['s_d0'])
threedee.scatter(temp, hum, s_d0_l)

threedee.set_xlabel('s_t0')
threedee.set_ylabel('s_h0')
threedee.set_zlabel('s_d0')
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

pm25_temperature_humidity_data_group = pm25_data.groupby(['s_t0','s_h0'])[['s_d0', 's_d1']]
pm25_temperature_humidity_data_mean = pm25_temperature_humidity_data_group.mean()
group_keys = pm25_temperature_humidity_data_group.groups.keys()

temp = []
hum = []
for items in group_keys : 
    (temp_val, hum_val) = items
    temp.append(temp_val)
    hum.append(hum_val)

plt.figure(1)
ax = plt.figure()
threedee = ax.gca(projection='3d')
print("type(threedee) = {x}".format(x = type(threedee)))
threedee.scatter(temp, hum, pm25_temperature_humidity_data_mean['s_d0'], c = 'Pink')
threedee.scatter(temp, hum, pm25_temperature_humidity_data_mean['s_d1'], c = 'Green')

threedee.set_xlabel('s_t0')
threedee.set_ylabel('s_h0')
threedee.set_zlabel(['s_d0', 's_d1'])
plt.show()

#pm25_temperature_humidity_data['s_d0']
print(pm25_temperature_humidity_data_mean['s_d0'])

plt.figure(2)
threedee = plt.figure().gca(projection='3d')
threedee.scatter(temp, hum, pm25_temperature_humidity_data_mean['s_d1'], c = 'b')

threedee.set_xlabel('s_t0')
threedee.set_ylabel('s_h0')
threedee.set_zlabel('s_d1')
plt.show()
print(pm25_temperature_humidity_data_mean['s_d1'])
# Out:
# type(threedee) = <class 'matplotlib.axes._subplots.Axes3DSubplot'>
# s_t0   s_h0
# 0.00   0.00      8.090909
# 15.20  1.00     32.000000
#        99.90    17.000000
# 15.90  99.90    16.000000
# 16.90  1.00      4.000000
# 17.60  99.90    17.000000
# 17.70  1.00      7.000000
# 18.10  84.70    21.000000
# 18.40  99.90    18.500000
# 18.50  81.90    15.000000
# 18.80  56.00    28.000000
# 20.00  99.90    16.000000
# 21.50  91.10     5.500000
# 23.90  99.90    22.000000
# 24.30  99.90    21.000000
# 25.00  99.90    17.500000
# 25.10  99.90    20.315789
# 25.20  74.80     8.000000
#        99.90    20.094118
# 25.30  99.90    20.364865
# 25.40  99.90    20.035088
# 25.50  74.90    10.000000
#        92.20    15.000000
#        99.90    20.507463
# 25.60  1.40     15.500000
#        7.20      6.000000
#        25.50    11.500000
#        55.30     8.000000
#        55.60     5.500000
#        74.20    16.000000
#                   ...
# 39.24  48.68    18.000000
# ...

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

pm25_temperature_humidity_data_group = pm25_data.groupby(['s_t0','s_h0'])[['s_d0', 's_d1']]
pm25_temperature_humidity_data_mean = pm25_temperature_humidity_data_group.mean()
group_keys = pm25_temperature_humidity_data_group.groups.keys()

temp = []
hum = []
for items in group_keys : 
    (temp_val, hum_val) = items
    temp.append(temp_val)
    hum.append(hum_val)

plt.figure(1)
threedee = plt.figure().gca(projection='3d')
threedee.scatter(temp, hum, pm25_temperature_humidity_data_mean['s_d0'])

threedee.set_xlabel('s_t0')
threedee.set_ylabel('s_h0')
threedee.set_zlabel('s_d0')
plt.show()

#pm25_temperature_humidity_data['s_d0']
print(pm25_temperature_humidity_data_mean.loc[15.2, 99.9]['s_d0'])
x = pm25_temperature_humidity_data_mean.loc[15.2, 1]['s_d0']
print("type(x) = {x}".format(x = type(x)))
print("x = {x}".format(x = x))
print("---")
print("test = {x}".format(x = pm25_temperature_humidity_data_group.get_group((15.2, 1))['s_d0']))
print("---")
for val in pm25_temperature_humidity_data_group.get_group((15.2, 99.9))['s_d0']:
    print("val = {x}".format(x = val))
print("---")
print(pm25_temperature_humidity_data_mean['s_d0'])

plt.figure(2)
threedee = plt.figure().gca(projection='3d')
threedee.scatter(temp, hum, pm25_temperature_humidity_data_mean['s_d1'], c = 'b')

threedee.set_xlabel('s_t0')
threedee.set_ylabel('s_h0')
threedee.set_zlabel('s_d1')
plt.show()
print(pm25_temperature_humidity_data_mean['s_d1'])
# Out:
# 17.0
# type(x) = <class 'numpy.float64'>
# x = 32.0
# ---
# test = 5321    32.0
# Name: s_d0, dtype: float64
# ---
# val = 17.0
# val = 17.0
# ---
# s_t0   s_h0
# 0.00   0.00      8.090909
# 15.20  1.00     32.000000
#        99.90    17.000000
# 15.90  99.90    16.000000
# 16.90  1.00      4.000000
# 17.60  99.90    17.000000
# 17.70  1.00      7.000000
# 18.10  84.70    21.000000
# 18.40  99.90    18.500000
# 18.50  81.90    15.000000
# 18.80  56.00    28.000000
# 20.00  99.90    16.000000
# 21.50  91.10     5.500000
# 23.90  99.90    22.000000
# 24.30  99.90    21.000000
# 25.00  99.90    17.500000
# 25.10  99.90    20.315789
# 25.20  74.80     8.000000
#        99.90    20.094118
# 25.30  99.90    20.364865
# 25.40  99.90    20.035088
# 25.50  74.90    10.000000
#        92.20    15.000000
#        99.90    20.507463
# 25.60  1.40     15.500000
#        7.20      6.000000
#        25.50    11.500000
#        55.30     8.000000
#        55.60     5.500000
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl

mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure()
ax = fig.gca(projection='3d')

pm25_temperature_humidity_data_group = pm25_data.groupby(['s_t0','s_h0'])[['s_d0', 's_d1']]
pm25_temperature_humidity_data_mean = pm25_temperature_humidity_data_group.mean()
group_keys = pm25_temperature_humidity_data_group.groups.keys()

temp = []
hum = []
for items in group_keys : 
    (temp_val, hum_val) = items
    temp.append(temp_val)
    hum.append(hum_val)

s_d0_l = []
for item in pm25_temperature_humidity_data_mean['s_d0']:
    s_d0_l.append(item)
    
X = temp
Y = hum
#X, Y = np.meshgrid(X, Y)
Z = s_d0_l




#print(pm25_temperature_humidity_data_mean)
#type(pm25_temperature_humidity_data_mean)
#pm25_temperature_humidity_data_mean.get_value.at(0, 0)
#print(pm25_temperature_humidity_data_mean.iloc[::])
#for item in pm25_temperature_humidity_data_mean.iloc[::]:
#    print(item)

  

    
ax.plot(X, Y, Z, label='s_d0', c='y')
ax.legend()
plt.show()
#print(pm25_temperature_humidity_data_mean['s_d0'])

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

plt.figure(1)
threedee = plt.figure().gca(projection='3d')
threedee.scatter(pm25_data['s_t0'], pm25_data['s_h0'], pm25_data['s_d0'])

threedee.set_xlabel('s_t0')
threedee.set_ylabel('s_h0')
threedee.set_zlabel('s_d0')
plt.show()

plt.figure(2)
threedee = plt.figure().gca(projection='3d')
threedee.scatter(pm25_data['s_t0'], pm25_data['s_h0'], pm25_data['s_d1'], c = 'b')

threedee.set_xlabel('s_t0')
threedee.set_ylabel('s_h0')
threedee.set_zlabel('s_d1')
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

pm25_temperature_humidity_data_group = pm25_data.groupby(['s_h0','s_t0'])[['s_d0', 's_d1']]
pm25_temperature_humidity_data_mean = pm25_temperature_humidity_data_group.mean()
group_keys = pm25_temperature_humidity_data_group.groups.keys()

temp = []
hum = []
for items in group_keys : 
    (temp_val, hum_val) = items
    temp.append(temp_val)
    hum.append(hum_val)

#print(temp)
#print(hum)

print("type = {x}".format(x = type(pm25_temperature_humidity_data_mean)))


plt.figure(1)
threedee = plt.figure().gca(projection='3d')
threedee.scatter(temp, hum, pm25_temperature_humidity_data_mean['s_d0'])

threedee.set_xlabel('s_h0')
threedee.set_ylabel('s_t0')
threedee.set_zlabel('s_d0')
plt.show()

#pm25_temperature_humidity_data['s_d0']
print(pm25_temperature_humidity_data_mean['s_d0'])

plt.figure(2)
threedee = plt.figure().gca(projection='3d')
threedee.scatter(temp, hum, pm25_temperature_humidity_data_mean['s_d1'], c = 'b')

threedee.set_xlabel('s_h0')
threedee.set_ylabel('s_t0')
threedee.set_zlabel('s_d1')
plt.show()
print(pm25_temperature_humidity_data_mean['s_d1'])
# Out:
# type = <class 'pandas.core.frame.DataFrame'>
# s_h0  s_t0
# 0.0   0.0      8.090909
# 0.2   26.5     9.333333
# 1.0   15.2    32.000000
#       16.9     4.000000
#       17.7     7.000000
#       25.7     3.000000
#       25.8     9.000000
#       26.0     6.600000
#       26.2     7.000000
#       26.3     3.000000
#       26.4     7.268657
#       26.5     7.858491
#       26.6     6.875000
#       26.7     7.000000
#       26.8     4.524194
#       26.9     4.016129
#       27.0     3.812500
#       27.1     6.647059
#       27.2     9.684211
#       27.3    11.750000
#       27.4     9.024390
#       27.5     9.043478
#       27.6     6.620690
#       27.7     8.363636
#       27.8    11.800000
#       27.9    15.333333
#       28.0    14.000000
#       28.1     8.500000
#       28.2    15.000000
#       28.3    17.000000
#                 ...
# 99.9  29.8    13.150000
#       29.9    12.978261
#       30.0    14.536082
#       30.1    16.031250
#       30.2    17.234043
# ...

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
#matplotlib

pm25_lon_lat_data_group = pm25_data.groupby(['gps_lon','gps_lat'])[['s_d0', 's_d1']]
pm25_lon_lat_data_mean = pm25_lon_lat_data_group.mean()
group_keys = pm25_lon_lat_data_group.groups.keys()

lon = []
lan = []
for items in group_keys : 
    (lon_val, lat_val) = items
    lon.append(lon_val)
    lan.append(lat_val)

#print(lon)
#print(lan)

plt.figure(1)
threedee = plt.figure().gca(projection='3d')
threedee.scatter(lon, lan, pm25_lon_lat_data_mean['s_d0'])

threedee.set_xlabel('gps_lon')
threedee.set_ylabel('gps_lat')
threedee.set_zlabel('s_d0')
plt.show()

#pm25_temperature_humidity_data['s_d0']
#print(pm25_lon_lat_data_group.count())
print(pm25_data.groupby(['gps_lon','gps_lat'])[['s_d0', 's_d1']].count())
#print(pm25_lon_lat_data_mean['s_d0'])

plt.figure(2)
threedee = plt.figure().gca(projection='3d')
threedee.scatter(lon, lan, pm25_lon_lat_data_mean['s_d1'], c = 'b')

threedee.set_xlabel('gps_lon')
threedee.set_ylabel('gps_lat')
threedee.set_zlabel('s_d1')
plt.show()
#print(pm25_lon_lat_data_mean['s_d1'])
# Out:
#                       s_d0  s_d1
# gps_lon    gps_lat
# 120.344875 22.631400     3     3
# 120.344878 22.631463     6     6
# 120.344885 22.631435     3     3
# 120.344887 22.631402     7     7
# 120.344890 22.631468     2     2
# 120.344893 22.631445     4     4
# 120.344895 22.631288     1     1
# 120.344897 22.631312     3     3
# 120.344900 22.631442     2     2
# 120.344907 22.631355    10    10
# 120.344913 22.631408     9     9
# 120.344923 22.631373     4     4
# 120.344932 22.631367     4     4
#            22.631458     6     6
# 120.344935 22.631448     2     2
# 120.344937 22.631365     8     8
# 120.344942 22.631452     3     3
# 120.344945 22.631298     1     1
#            22.631360     4     4
#            22.631417     7     7
# 120.344952 22.631325     1     1
#            22.631392     3     3
# 120.344955 22.631332     1     1
#            22.631362    10    10
#            22.631365     2     2
#            22.631417     4     4
# ...

# %%
print(pm25_data['gps_lon'].unique())
print(pm25_data['gps_lat'].unique())
# Out:
# [ 121.51793333  121.51798167  121.51795333 ...,  121.51879333  121.518745
#   121.518975  ]
# [ 24.98507167  24.985215    24.98512167 ...,  24.98468833  24.984765
#   24.984745  ]

# %%
#pm25_temperature_data = pm25_data.groupby(pm25_data['s_t0'])[['s_d0', 's_d1']].mean()
pm25_temperature_data = pm25_data.groupby('gps_lon')[['s_d0', 's_d1']].mean()
max_tmp = max(pm25_data['gps_lon'])
min_tmp = min(pm25_data['gps_lon'])
tmp_range = int(max_tmp - min_tmp)
print("max_tmp = {x}".format(x = max_tmp))
print("min_tmp = {x}".format(x = min_tmp))
print("tmp_range = {x}".format(x = tmp_range))
pm25_temperature_data.plot(title = 'PM2.5 and PM10 VS Temperature', rot = 70, xticks = range(int(min_tmp), int(max_tmp)))
# Out:
# max_tmp = 121.762851667
# min_tmp = 120.344875
# tmp_range = 1

# %%
# %matplotlib inline
pm25_temperature_data = pm25_data.groupby('gps_lat')[['s_d0', 's_d1']].mean()
max_tmp = max(pm25_data['gps_lat'])
min_tmp = min(pm25_data['gps_lat'])
tmp_range = int(max_tmp - min_tmp)
print("max_tmp = {x}".format(x = max_tmp))
print("min_tmp = {x}".format(x = min_tmp))
print("tmp_range = {x}".format(x = tmp_range))
pm25_temperature_data.plot(title = 'PM2.5 and PM10 VS Temperature', rot = 70, xticks = range(int(min_tmp), int(max_tmp)))
# Out:
# max_tmp = 25.2737783333
# min_tmp = 22.63126
# tmp_range = 2
